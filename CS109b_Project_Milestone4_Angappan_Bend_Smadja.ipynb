# %% [markdown]
# # CS109b - Project - Milestone 4
#
# ## Sathish Angappan, Hannah Bend, Yohann Smadja
#
# In this notebook we use Keras to run a first convolution neural network. Even though our network did not learn anything... we did!  We also looked at the ResNet50 pre-trained network to see how it compared to ours.
#
# _Installing/uploading libraries on the AWS instance_

# %%
# !pip3 install Pillow
# Out:
# ...
#     100% |████████████████████████████████| 5.7MB 269kB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 81kB 13.3MB/s ta 0:00:01
# ...
# done
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/20/58/49/cc7bd00345397059149a10b0259ef38b867935ea2ecff99a9b
# Successfully built olefile
# ...
# You are using pip version 8.1.1, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip3 install h5py
# Out:
# ...
#     100% |████████████████████████████████| 4.7MB 317kB/s eta 0:00:01
# ...
#   Using cached six-1.10.0-py2.py3-none-any.whl
# ...
#   Using cached numpy-1.12.1-cp35-cp35m-manylinux1_x86_64.whl
# ...
# You are using pip version 8.1.1, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from __future__ import print_function

from PIL import Image

import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten
from keras.optimizers import SGD
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img, list_pictures

import h5py

import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

from sklearn.cross_validation import train_test_split
import pandas as pd
import numpy as np
# Out:
# Using TensorFlow backend.
# /home/ubuntu/.local/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# # 1. Train a model from scratch
#
# This week we run our first convolution neural networks on posters only. To keep things simple we will first use 200 images from only two genres: Action and Drama. We started with a small model with "only" 335K parameters to tune. With such a small number of observations, we did not expect anything to be learned and didn't see any miracles.
#
# We uploaded onto an EC2 m4.large instance 200 posters using FileZilla. Almost all the images have a 750 by 500 resolution but some had a slightly different one. We used matplotlib's resize function to make sure the resolution was exactly the same for all images. We failed to use the load_img function from Keras. We kept getting an error message that the library PIL was missing despite successfull install and import. It does seem that the resolution is quite high and we should be able to reduce it to 500 by 350 or even further and not lose too much information.
#
# For simplicity we started with only two classes. 100 of the posters were from action movies and the last 100 were dramas. Hence the two classes were balanced. We split the dataset into two subsets: a training with 160 posters and a validation test with 40 of them. Obviously this is a very low number of inputs for such a complicated task to classify posters by genre but this is our very first model.

# %%
# list img from directory
path = '/home/ubuntu/SharedVB/Posters/'
posters = list_pictures(path)
print()
posters[:3]
# Out:
# ['/home/ubuntu/SharedVB/Posters/296360_1_35.jpg',
#  '/home/ubuntu/SharedVB/Posters/290825_1_35.jpg',
#  '/home/ubuntu/SharedVB/Posters/291264_1_35.jpg']

# %%
# prepare the data
x = []
y = []

for poster in posters:
    #img = load_img(poster, target_size =(750, 500)) # requires PIL whereas PIL is running... don't understand why
    img = Image.open(poster)
    img = img.resize((350, 500))
    img_array = img_to_array(img)
    if (img_array.shape != (500, 350, 3)):
        print(poster, img_array.shape)
    x.append(img_array)
    y.append(int(poster[-6:-4]))
    
x = np.asarray(x)
y = np.asarray(y)
print("x shape:", x.shape)
print("y shape:", y.shape)
# Out:
# x shape: (200, 500, 350, 3)
# y shape: (200,)

# %%
# create training and testing set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
del x, y
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (160, 500, 350, 3) (40, 500, 350, 3) (160,) (40,)

# %%
# input image dimensions
img_rows, img_cols = 500, 350

# we have two types of movie genre
num_classes = 2

# %%
# classes should be coded with 0 or 1 for Keras' function below
y_train[y_train == 35] = 1
y_train[y_train == 28] = 0
y_test[y_test == 35] = 1
y_test[y_test == 28] = 0

# convert class vectors to binary class matrices
# keras likes one hot encoding instead of class names
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
# Normalize image values to [0,1]
# interestingly the keras example code does not center the data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    input_shape = (3, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)
print("Input shape:", input_shape)
# Out:
# Input shape: (500, 350, 3)

# %% [markdown]
# ## 1.a Setting up our model
#
# For this first model we were able to use a GPU, where the model we had started last week did not. In order to have our model run rather quickly we limit the number of epochs to 100 and the batch size to 64 to compute the gradient.
#
# The model included two convolution layers each followed by maxpool layers. Each convolution layer had 8 neurones and the kernel filters were 4 by 4 for the first layer and 3 by 3 for the second one with rectified linear unit ("ReLU") as activation function. The last layer is a fully connected one with 4 neurones with the same activation function. Finally, since this is a binary problem (only two classes), the output layer is using a sigmoid function. Even though the model seems rather small, the number of parameters is close to 730,000.  The size of the input (750 by 500 images) is the main reason why there are so many parameters.
#
# We used a large learning rate of 0.1 because of the low number of epochs. Even though we do not expect much from this first model a small learning rate with a low number of epochs was a dead-from-the-start strategy. At least with a high learning rate we can see if the accuracy starts increasing even slightly above 50% to give us a hint if we are on the right path.

# %%
# Load a previous network model?
#old_model = load_model('my_old_model.h5')

# %%
# smaller batch size means noisier gradient, but more updates per epoch
batch_size = 64 #128? 256? 512?

# number of iterations over the complete training data
epochs = 100

# %%
# or create an empty network model?
model = Sequential()

# --- input layer ---
model.add(Conv2D(8, kernel_size=(4,4), activation='relu', input_shape=input_shape))
# --- max pool ---
model.add(MaxPooling2D(pool_size=(2, 2)))

# --- next layer ---
# we could double the number of filters as max pool made the 
# feature maps much smaller 
# just not doing this to improve runtime
model.add(Conv2D(8, kernel_size=(3, 3), activation='relu'))
# --- max pool ---
model.add(MaxPooling2D(pool_size=(2, 2)))

# flatten for fully connected classification layer
model.add(Flatten())
# note that the 2 is the number of classes we have
# the classes are mutually exclusive so softmax is a good choice
# --- fully connected layer ---
model.add(Dense(4, activation='relu'))

# --- classification ---
model.add(Dense(2, activation='sigmoid'))  #binary case
#model.add(Dense(num_classes, activation='softmax'))  #multiclasses case

# prints out a summary of the model architecture
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 497, 347, 8)       392
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 248, 173, 8)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 246, 171, 8)       584
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 123, 85, 8)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 83640)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 334564
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 10
# ...
# Total params: 335,550.0
# ...

# %%
# this does all necessary compiling. In tensorflow this is much quicker than in theano
# the setup is our basic categorical crossentropy with stochastic gradient decent
# we also specify that we want to evaluate our model in terms of accuracy
sgd = SGD(lr=0.1, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy']) # binary case
#model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy']) # multiple classes case

# %% [markdown]
# ## 1.b Running our model

# %%
# this is now the actual training
# in addition to the training data we provide validation data
# this data is used to calculate the performance of the model over all the epochs
# this is useful to determine when training should stop
# in our case we just use it to monitor the evolution of the model over the training epochs
# if we use the validation data to determine when to stop the training or which model to save, we 
# should not use the test data, but a separate validation set. 
history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))

# once training is complete, let's see how well we have done
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 160 samples, validate on 40 samples
# Epoch 1/100
# 160/160 [==============================] - 2s - loss: 0.7099 - acc: 0.4719 - val_loss: 0.6917 - val_acc: 0.5250
# Epoch 2/100
# 160/160 [==============================] - 1s - loss: 0.6929 - acc: 0.4937 - val_loss: 0.6924 - val_acc: 0.5250
# Epoch 3/100
# 160/160 [==============================] - 1s - loss: 0.6913 - acc: 0.4937 - val_loss: 0.6911 - val_acc: 0.5250
# Epoch 4/100
# 160/160 [==============================] - 1s - loss: 0.6892 - acc: 0.4937 - val_loss: 0.6916 - val_acc: 0.5250
# Epoch 5/100
# 160/160 [==============================] - 1s - loss: 0.6787 - acc: 0.5250 - val_loss: 0.7073 - val_acc: 0.5250
# Epoch 6/100
# 160/160 [==============================] - 1s - loss: 0.6937 - acc: 0.5156 - val_loss: 0.6946 - val_acc: 0.5125
# Epoch 7/100
# 160/160 [==============================] - 1s - loss: 0.6804 - acc: 0.5500 - val_loss: 0.6861 - val_acc: 0.5875
# Epoch 8/100
# ...

# %%
# list all data in history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# PLOT MORE THAN JUST THE ACC? ACC ON VALIDATION AS WELL?

# %%
### save model so you can continue working on it and load it later.

#model.save('/home/ubuntu/100epocs1.h5') #creates a HDF5 file

# %%
# Look at the weights of the first layer
layer = model.layers[0]
# this actually returns a list 
# first element is W
# second element are all the biases b
weights = layer.get_weights()
# the weights are the number of pixels times the number of filters (hidden units)
print("Shape of W")
print(weights[0].shape)
# Out:
# Shape of W
# (4, 4, 3, 8)

# %%
# make a figure for the first 8 filters
index = 0
for i in range(4):
    for j in range(2):
        w = weights[0][:,:,0,index]
        w = w.reshape(4,4)
        index+=1
        plt.subplot(4,4,index)
        plt.imshow(w, cmap='gray')    

plt.show()

# %% [markdown]
# ## 1.c A second, larger model
#
# We then uploaded 5000 posters and looked at a more serious model with more neurones, more layers and lower learning rates. Before getting started, we confirmed there were no posters from identical movies in the two datasets of action and drama movies.  We kept our parameters the same, with the exception of batch size, which we increased to 256.

# %%
# list img from directory
path_action = '/home/ubuntu/Action 2010'
list_action = list_pictures(path_action)
path_drama = '/home/ubuntu/drama 2500'
list_drama = list_pictures(path_drama)

list_drama_id = []
list_action_id = []

for f in list_drama:
    list_drama_id.append(f[24:-9])
for f in list_action:
    list_action_id.append(f[24:-9])  

k=0
for f in list_drama_id:
    if (f in list_action_id):
        k +=1
print(k)
# Out:
# 0

# %%
posters = list_action + list_drama

x = []
y = []

# Convert grayscal images (w, h, 1) arrays into rgb images (w, h, 3) arrays
def to_rgb(im):
    w, h, one = im.shape
    ret = np.empty((w, h, 3), dtype=np.uint8)
    ret[:, :, 0] = im[:, :, 0]
    ret[:, :, 1] = im[:, :, 0]
    ret[:, :, 2] = im[:, :, 0]
    return ret

for poster in posters:
    #img = load_img(poster, target_size =(750, 500)) # "requires PIL" whereas PIL is running... don't understand why
    img = Image.open(poster)
    img = img.resize((200, 320))
    img_array = img_to_array(img)
    if (img_array.shape == (320, 200, 1)):
        img_array = to_rgb(img_array)
    if (img_array.shape != (320, 200, 3)):
        print(poster, img_array.shape)
    x.append(img_array)
    y.append(int(poster[-6:-4]))
    
x = np.asarray(x)
y = np.asarray(y)
print("x shape:", x.shape)
print("y shape:", y.shape)
# Out:
# x shape: (5110, 320, 200, 3)
# y shape: (5110,)

# %%
# create training and testing set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
del x, y
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (4088, 320, 200, 3) (1022, 320, 200, 3) (4088,) (1022,)

# %%
# input image dimensions
img_rows, img_cols = 320, 200

# we have two types of movie genre
num_classes = 2

# %%
# classes should be coded with 0 or 1 for Keras' function below
y_train[y_train == 18] = 1
y_train[y_train == 28] = 0
y_test[y_test == 18] = 1
y_test[y_test == 28] = 0

# convert class vectors to binary class matrices
# keras likes one hot encoding instead of class names
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
# Normalize image values to [0,1]
# interestingly the keras example code does not center the data
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# %%
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 3, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 3, img_rows, img_cols)
    input_shape = (3, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 3)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)
print("Input shape:", input_shape)
# Out:
# Input shape: (320, 200, 3)

# %% [markdown]
# ### 1.c.i Setting up our second model

# %%
# smaller batch size means noisier gradient, but more updates per epoch
batch_size = 256 #64? #128? 256? 512?

# number of iterations over the complete training data
epochs = 100

# %%
# or create an empty network model?
model = Sequential()

# --- input layer ---
model.add(Conv2D(8, kernel_size=(5,5), activation='relu', input_shape=input_shape))
# --- max pool ---
model.add(MaxPooling2D(pool_size=(2, 2)))

# --- next layer ---
# we could double the number of filters as max pool made the 
# feature maps much smaller 
# just not doing this to improve runtime
model.add(Conv2D(16, kernel_size=(4, 4), activation='relu'))
# --- max pool ---
model.add(MaxPooling2D(pool_size=(2, 2)))

# --- next layer ---
# we could double the number of filters as max pool made the 
# feature maps much smaller 
# just not doing this to improve runtime
model.add(Conv2D(16, kernel_size=(3, 3), activation='relu'))
# --- max pool ---
model.add(MaxPooling2D(pool_size=(2, 2)))


# flatten for fully connected classification layer
model.add(Flatten())
# note that the 2 is the number of classes we have
# the classes are mutually exclusive so softmax is a good choice
# --- fully connected layer ---
model.add(Dense(8, activation='relu'))

# --- classification ---
model.add(Dense(2, activation='sigmoid'))  #binary case
#model.add(Dense(num_classes, activation='softmax'))  #multiclasses case

# prints out a summary of the model architecture
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_7 (Conv2D)            (None, 316, 196, 8)       608
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 158, 98, 8)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 155, 95, 16)       2064
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 77, 47, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 75, 45, 16)        2320
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 37, 22, 16)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 13024)             0
# ...

# %% [markdown]
# ### 1.c.ii Running our second model

# %%
sgd = SGD(lr=0.1, momentum=0.9)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy']) # binary case

history = model.fit(x_train, y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 4088 samples, validate on 1022 samples
# Epoch 1/100
# 4088/4088 [==============================] - 17s - loss: 0.6986 - acc: 0.5227 - val_loss: 0.6994 - val_acc: 0.4677
# Epoch 2/100
# 4088/4088 [==============================] - 13s - loss: 0.6960 - acc: 0.4946 - val_loss: 0.6968 - val_acc: 0.4677
# Epoch 3/100
# 4088/4088 [==============================] - 13s - loss: 0.6938 - acc: 0.5002 - val_loss: 0.6913 - val_acc: 0.5323
# Epoch 4/100
# 4088/4088 [==============================] - 13s - loss: 0.6933 - acc: 0.5054 - val_loss: 0.6920 - val_acc: 0.5323
# Epoch 5/100
# 4088/4088 [==============================] - 13s - loss: 0.6933 - acc: 0.4917 - val_loss: 0.6935 - val_acc: 0.4677
# Epoch 6/100
# 4088/4088 [==============================] - 13s - loss: 0.6932 - acc: 0.4961 - val_loss: 0.6925 - val_acc: 0.5323
# Epoch 7/100
# 4088/4088 [==============================] - 13s - loss: 0.6932 - acc: 0.5054 - val_loss: 0.6927 - val_acc: 0.5323
# Epoch 8/100
# ...

# %%
# list all data in history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ### 1.c.iii Reducing the learning rate
#
# We see that after only a few epochs the CNN does not learn anymore suggesting our learning rate might be too high. Let's keep learning with a smaller rate for 20 epochs and a learning rate of 0.01 to see what happens.

# %%
model.save('/home/ubuntu/CNN_500_0.1.h5') #creates a HDF5 file

# %%
model = load_model('/home/ubuntu/CNN_500_0.1.h5')
model.optimizer.lr.assign(0.01)

history = model.fit(x_train, y_train, batch_size=batch_size, epochs=20, verbose=1, validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 4088 samples, validate on 1022 samples
# Epoch 1/20
# 4088/4088 [==============================] - 13s - loss: 0.6931 - acc: 0.5054 - val_loss: 0.6922 - val_acc: 0.5323
# Epoch 2/20
# 4088/4088 [==============================] - 13s - loss: 0.6933 - acc: 0.5054 - val_loss: 0.6928 - val_acc: 0.5323
# Epoch 3/20
# 4088/4088 [==============================] - 13s - loss: 0.6931 - acc: 0.5054 - val_loss: 0.6925 - val_acc: 0.5323
# Epoch 4/20
# 4088/4088 [==============================] - 13s - loss: 0.6931 - acc: 0.5054 - val_loss: 0.6923 - val_acc: 0.5323
# Epoch 5/20
# 4088/4088 [==============================] - 13s - loss: 0.6931 - acc: 0.5054 - val_loss: 0.6925 - val_acc: 0.5323
# Epoch 6/20
# 4088/4088 [==============================] - 13s - loss: 0.6932 - acc: 0.5054 - val_loss: 0.6930 - val_acc: 0.5323
# Epoch 7/20
# 4088/4088 [==============================] - 13s - loss: 0.6932 - acc: 0.5054 - val_loss: 0.6924 - val_acc: 0.5323
# Epoch 8/20
# ...

# %%
# list all data in history
#print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## 1.d Initial conclusions
#
# * The GPU made a vast difference in our computation times, with rates decreasing from 50 seconds per epoch on a CPU to 2 seconds per epoch on the GPU.  Obviously, the GPU will be the way to go, especially given our final dataset could have tens of thousands of posters.
#
# * We continuously had to reduce the resolution to make any progress.  We were able to run a model on the GPU with a resolution of 500x350 with only 200 observations, but when we increased the number of observations to 5,000 we had to reduce the resolution again to 320x200.
#
# * Should we continue to attempt to categorize each poster by one genre, we'll need to ensure that our poster images are unique, a one-to-one association between genre and image.
#
# * Our best accuracy was around 53%, ignoring a spike of 63% on our very first model.  A smaller learning rate didn't return better results for our larger model; instead, it appears our learning essentially flatlined, with one pulse at the tenth epoch.  Not what we were hoping to see.

# %% [markdown]
# # 2. Try a pre-trained model
#
# Let's try a different approach. We use below the pretrained ResNet50 model combined with an SVM to classify our images.
#
# We don't actually use the full model. The first convolution layers are preparing the features that the last fully connected layer uses to classify images from the ImageNet dataset into 1,000 classes. In our problem we only have two classes and we are trying to predict genres. We use an SVM to do the actual genre classification using the features extracted by the first layers.
#
# For the ResNet50 model, we exclude the last fully connected, incorporated the pre-trained 'imagenet' weights, altered the default shape to our smaller 320x200 and opted not to use any pooling.
#
# _(two cells accidentally deleted after exporting from AWS, hence not executed below)_

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
# set up ResNet50 model, minus the top layer
model_resnet50 = ResNet50(include_top=False, weights='imagenet', input_shape=(200,320))

# %%
posters = list_action + list_drama

x = []
y = []

# Convert grayscal images (w, h, 1) arrays into rgb images (w, h, 3) arrays
def to_rgb(im):
    w, h, one = im.shape
    ret = np.empty((w, h, 3), dtype=np.uint8)
    ret[:, :, 0] = im[:, :, 0]
    ret[:, :, 1] = im[:, :, 0]
    ret[:, :, 2] = im[:, :, 0]
    return ret

for poster in posters:
    #img = load_img(poster, target_size =(750, 500)) # "requires PIL" whereas PIL is running... don't understand why
    img = Image.open(poster)
    img = img.resize((200, 320))
    img_array = img_to_array(img)
    if (img_array.shape == (320, 200, 1)):
        img_array = to_rgb(img_array)
    if (img_array.shape != (320, 200, 3)):
        print(poster, img_array.shape)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array.astype('float32')
    img_array = preprocess_input(img_array)
    pred = model_resnet50.predict(img_array) ## use ResNet model to predict
    x.append(pred[0,0,0,:])
    y.append(int(poster[-6:-4]))
    
x = np.asarray(x)
y = np.asarray(y)
print("x shape:", x.shape)
print("y shape:", y.shape)
# Out:
# x shape: (5110, 2048)
# y shape: (5110,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (4088, 2048) (1022, 2048) (4088,) (1022,)

# %% [markdown]
# ## 2.a Create SVM models using ResNet features
#
# Running low on time, we "tuned" the SVM models by setting up four, adjusting for cost and linear vs radial.

# %%
from sklearn import svm

clf1_rbf = svm.SVC(C=1, kernel='rbf')
clf1_rbf.fit(x_train, y_train)  
y_pred1_rbf = clf1_rbf.predict(x_test)

clf01_rbf = svm.SVC(C=0.1, kernel='rbf')
clf01_rbf.fit(x_train, y_train)  
y_pred01_rbf = clf01_rbf.predict(x_test)

clf1_lin = svm.SVC(C=1, kernel='linear')
clf1_lin.fit(x_train, y_train)  
y_pred1_lin= clf01_rbf.predict(x_test)

clf01_lin = svm.SVC(C=0.1, kernel='linear')
clf01_lin.fit(x_train, y_train)  
y_pred01_lin= clf01_rbf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
import itertools

class_names = ["Drama","Action"]

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    print("Overall accuracy: ", round(cm.trace()/(cm.sum()+0.0),3))

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Compute confusion matrix
cnf_matrix1_rbf = confusion_matrix(y_test, y_pred1_rbf)
cnf_matrix01_rbf = confusion_matrix(y_test, y_pred01_rbf)
cnf_matrix1_lin = confusion_matrix(y_test, y_pred1_lin)
cnf_matrix01_lin = confusion_matrix(y_test, y_pred01_lin)
np.set_printoptions(precision=2)

# Plot normalized confusion matrix
plt.figure()
print("RBF Kernel - C=1")
plot_confusion_matrix(cnf_matrix1_rbf, classes=class_names, normalize=False, title='Normalized confusion matrix')
plt.show()

plt.show()
# Out:
# RBF Kernel - C=1
# Overall accuracy:  0.834

# %% [markdown]
# ## 2.b Pre-training conclusions
#
# * Using the ResNet50 model as a feature extractor combined with a simple RBF SVM with a penalization C=1 we get an impressive classification rate of 83.4%. Other parameters led to an accuracy sub 80%.
#
# * It's easy to see why pre-training is more common, as the results from such a massive dataset were significantly more accurate than our from-scratch models.

# %% [markdown]
# # 3 Exploratory Ideas
#
# Multilabel is a classification problem where multiple target labels can be assigned to each observation (i.e. poster) instead of only one like in multiclass classification. We also tried to explore Multi Label Classification for the movie posters. Many movies that were released had more than one genre associated to it. In a multi class scenario, these genres are mutually exclusive.
#
# Several problem transformation methods exist for multi-label classification; the baseline approach: i.e binary relevance method, amounts to independently training one binary classifier for each label. Given an unseen sample, the combined model then predicts all labels for this sample for which the respective classifiers predict a positive result. This method of dividing the task into multiple binary tasks has something in common with the one-vs.-all (OvA, or one-vs.-rest, OvR) method for multiclass classification.
#
# __Adapted Algorithms__
#
# Some classification algorithms/models have been adaptated to the multi-label task, without requiring problem transformations. Examples of these include:
#
# boosting: AdaBoost.MH and AdaBoost.MR are extended versions of AdaBoost for multi-label data<br>
# k-nearest neighbors: the ML-kNN algorithm extends the k-NN classifier to multi-label data.<br>
# Decision trees<br>
# Kernel methods for vector output<br>
# Neural networks: BP-MLL is an adaptation of the popular back-propagation algorithm for multi-label learning<b4>
# scikit-multilearn: scikit contains a multilearn package for doing the multi label classification. However, this is not robust as NN.
#
# __Simple Implementation__
#
# Due to the complexity of neural networks and time constraints, we were not able to implement an example for the multi label classification. However, the following approach was considered. We planned to do one hot encoding of the genres of around 1000 movies. Use this matrix of genres(binary) as the y variable for the train and test data above. Then perform the classification using NN methodology and pretrained networks. Sample code is below.

# %%
import pandas as pd
df = pd.read_csv("tmdb2years.csv")
df.head()

# %%
import os
import PIL
from PIL import Image

x = []
y = []

images = os.listdir("./resized")
basewidth = 300
for img_jpg in images:
    img = Image.open('./resized/' + str(img_jpg))
    img_array = img_to_array(img)
    x.append(img_array)
    movie_id = str(img_jpg).split('.')[0]
    genres = df[(df['id'] == movie_id)][["genre1","genre2","genre3","genre4","genre5"]].values
    y.append(genres[0])
   
x = np.asarray(x)
y = np.asarray(y)
print('Multi Label Dimension: ' + str(y.shape))

# %%
# create training and testing set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
del x, y
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)

# %%
# input image dimensions
img_rows, img_cols = 500, 350

# we have a total of 18 genres in the selected movies.
num_classes = 18

# %% [markdown]
# # 4 Other Thoughts/Challenges
#
# Another exploratory idea could be to examine the relationship between the class predicted by ResNet and genre; is an image of a lit cigarette more likely to be a drama or a comedy?  If it is commonly associated with either, what additional visual clues do we use as humans to make that distinction?
#
# In terms of challenges, we are still struggling to find a storage solution for the thousands of images we downloaded. Every time we want start an instance we have to upload into the new instance the images. It takes around 15 minutes to upload 5K images via FileZila. We are considering using an S3 instance or just keep an instance open for the laat days of our project.
